# %%
import pandas as pd

# %%
# give information about data
# df = pd.read_csv("/content/demo.csv")

# %%
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  1200 non-null   object
#  1   Period            1200 non-null   float64
#  2   Data_value        1115 non-null   float64
#  3   Suppressed        0 non-null      float64
#  4   STATUS            1200 non-null   object
#  5   UNITS             1200 non-null   object
#  6   Magnitude         1200 non-null   int64
#  7   Subject           1200 non-null   object
#  8   Group             1200 non-null   object
#  9   Series_title_1    1200 non-null   object
#  10  Series_title_2    1200 non-null   object
#  11  Series_title_3    1200 non-null   object
#  12  Series_title_4    1200 non-null   object
#  13  Series_title_5    0 non-null      float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 131.4+ KB

# %%
# for run tsv files
# df = pd.read_csv("/content/sample-1.tsv" ,sep="\t")

# %%
# df.head(5)
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN    JANUARY        NaN        NaN        NaN        NaN
# 1         NaN          S          M          T          W          T
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN          2          3          4          5          6
# 4         NaN          9         10         11         12         13
#
#   Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9  ... Unnamed: 17 Unnamed: 18  \
# 0        NaN        NaN         NaN   FEBRUARY  ...       MARCH         NaN
# 1          F          S         NaN          S  ...           S           M
# 2        NaN          1         NaN        NaN  ...         NaN         NaN
# 3          7          8         NaN          6  ...           6           7
# 4         14         15         NaN         13  ...          13          14
#
#   Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  Unnamed: 23 Unnamed: 24  \
# ...

# %%
# for make first column as index
# df = pd.read_csv("/content/demo.csv", index_col='Series_reference')

# for make first column as header
# df = pd.read_csv("/content/demo.csv", index_col='Series_reference', header= 1)

# %%
# df.head(3)
# Out:
#                    Period  Data_value  Suppressed STATUS    UNITS  Magnitude  \
# Series_reference
# SSSQ.SFMN1111CA   2004.06    1248.356         NaN      F  dollars          6
# SSSQ.SFMN1111CA   2004.09    1220.571         NaN      F  dollars          6
# SSSQ.SFMN1111CA   2004.12    1263.820         NaN      F  dollars          6
#
#                                                     Subject  \
# Series_reference
# SSSQ.SFMN1111CA   Selected Services Survey (ANZSIC06) - SSS
# SSSQ.SFMN1111CA   Selected Services Survey (ANZSIC06) - SSS
# SSSQ.SFMN1111CA   Selected Services Survey (ANZSIC06) - SSS
#
#                                                             Group  \
# Series_reference
# SSSQ.SFMN1111CA   Industry sales - Subannual Financial Collection
# SSSQ.SFMN1111CA   Industry sales - Subannual Financial Collection
# SSSQ.SFMN1111CA   Industry sales - Subannual Financial Collection
#
#                                                      Series_title_1  \
# Series_reference
# ...

# %%
# for show specific columns
# df = pd.read_csv("/content/demo.csv", usecols=['Series_reference', 'Period', 'Data_value'])

# %%
# df.head(5)
# Out:
#   Series_reference   Period  Data_value
# 0  SSSQ.SFMN1111CA  2004.06    1248.356
# 1  SSSQ.SFMN1111CA  2004.09    1220.571
# 2  SSSQ.SFMN1111CA  2004.12    1263.820
# 3  SSSQ.SFMN1111CA  2005.03    1146.156
# 4  SSSQ.SFMN1111CA  2005.06    1382.692

# %%
# pandas series object
# df = pd.read_csv("/content/demo.csv", usecols=['Series_reference'], squeeze=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-3fc18094a4ea> in <cell line: 1>()
# ----> 1 pd.read_csv("/content/demo.csv", usecols=['Series_reference'], squeeze=True)
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %%
# for skip rows number 0 and 5
# df = pd.read_csv("/content/demo.csv", skiprows=[0,5])

# %%
# df.head(5)
# Out:
#    SSSQ.SFMN1111CA  2004.06  1248.356  Unnamed: 3  F  dollars  6  \
# 0  SSSQ.SFMN1111CA  2004.09  1220.571         NaN  F  dollars  6
# 1  SSSQ.SFMN1111CA  2004.12  1263.820         NaN  F  dollars  6
# 2  SSSQ.SFMN1111CA  2005.03  1146.156         NaN  F  dollars  6
# 3  SSSQ.SFMN1111CA  2005.09  1299.487         NaN  F  dollars  6
# 4  SSSQ.SFMN1111CA  2005.12  1343.035         NaN  F  dollars  6
#
#    Selected Services Survey (ANZSIC06) - SSS  \
# 0  Selected Services Survey (ANZSIC06) - SSS
# 1  Selected Services Survey (ANZSIC06) - SSS
# 2  Selected Services Survey (ANZSIC06) - SSS
# 3  Selected Services Survey (ANZSIC06) - SSS
# 4  Selected Services Survey (ANZSIC06) - SSS
#
#    Industry sales - Subannual Financial Collection  \
# 0  Industry sales - Subannual Financial Collection
# 1  Industry sales - Subannual Financial Collection
# 2  Industry sales - Subannual Financial Collection
# 3  Industry sales - Subannual Financial Collection
# ...

# %%
# for import only first 20 rows
# df = pd.read_csv("/content/demo.csv", nrows=20)

# %%
# df
# Out:
#    Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0   SSSQ.SFMN1111CA  2004.06    1248.356         NaN      F  dollars
# 1   SSSQ.SFMN1111CA  2004.09    1220.571         NaN      F  dollars
# 2   SSSQ.SFMN1111CA  2004.12    1263.820         NaN      F  dollars
# 3   SSSQ.SFMN1111CA  2005.03    1146.156         NaN      F  dollars
# 4   SSSQ.SFMN1111CA  2005.06    1382.692         NaN      F  dollars
# 5   SSSQ.SFMN1111CA  2005.09    1299.487         NaN      F  dollars
# 6   SSSQ.SFMN1111CA  2005.12    1343.035         NaN      F  dollars
# 7   SSSQ.SFMN1111CA  2006.03    1299.705         NaN      F  dollars
# 8   SSSQ.SFMN1111CA  2006.06    1469.855         NaN      F  dollars
# 9   SSSQ.SFMN1111CA  2006.09    1443.402         NaN      F  dollars
# 10  SSSQ.SFMN1111CA  2006.12    1455.796         NaN      F  dollars
# 11  SSSQ.SFMN1111CA  2007.03    1413.794         NaN      F  dollars
# 12  SSSQ.SFMN1111CA  2007.06    1583.683         NaN      F  dollars
# ...

# %%
# for specific encoding
# df = pd.read_csv("/content/demo.csv", encoding='latin-1')

# %%
# for skip rows that have extra column
# df = pd.read_csv("/content/demo.csv", on_bad_lines='skip')

# %%
# df
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0     SSSQ.SFMN1111CA  2004.06    1248.356         NaN      F  dollars
# 1     SSSQ.SFMN1111CA  2004.09    1220.571         NaN      F  dollars
# 2     SSSQ.SFMN1111CA  2004.12    1263.820         NaN      F  dollars
# 3     SSSQ.SFMN1111CA  2005.03    1146.156         NaN      F  dollars
# 4     SSSQ.SFMN1111CA  2005.06    1382.692         NaN      F  dollars
# ...               ...      ...         ...         ...    ...      ...
# 1195  SSSQ.SFRS2121CT  2023.03         NaN         NaN      C  dollars
# 1196  SSSQ.SFRS2121CT  2023.06         NaN         NaN      C  dollars
# 1197  SSSQ.SFRS2121CT  2023.09         NaN         NaN      C  dollars
# 1198  SSSQ.SFRS2121CT  2023.12         NaN         NaN      C  dollars
# 1199  SSSQ.SFRS2121CT  2024.03         NaN         NaN      C  dollars
#
#       Magnitude                                    Subject  \
# ...

# %%
# for change type of any column like here change int to float
# df = pd.read_csv("/content/demo.csv",dtype={'Magnitude': float})

# %%
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  1200 non-null   object
#  1   Period            1200 non-null   float64
#  2   Data_value        1115 non-null   float64
#  3   Suppressed        0 non-null      float64
#  4   STATUS            1200 non-null   object
#  5   UNITS             1200 non-null   object
#  6   Magnitude         1200 non-null   float64
#  7   Subject           1200 non-null   object
#  8   Group             1200 non-null   object
#  9   Series_title_1    1200 non-null   object
#  10  Series_title_2    1200 non-null   object
#  11  Series_title_3    1200 non-null   object
#  12  Series_title_4    1200 non-null   object
#  13  Series_title_5    0 non-null      float64
# dtypes: float64(5), object(9)
# memory usage: 131.4+ KB

# %%
# for change any column type as date
# df = pd.read_csv("/content/demo.csv", parse_dates=['Period'])
# df.info()

# %%
# df = pd.read_csv("/content/demo.csv")

# %%
# df.head(5)
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0  SSSQ.SFMN1111CA  2004.06    1248.356         NaN      F  dollars
# 1  SSSQ.SFMN1111CA  2004.09    1220.571         NaN      F  dollars
# 2  SSSQ.SFMN1111CA  2004.12    1263.820         NaN      F  dollars
# 3  SSSQ.SFMN1111CA  2005.03    1146.156         NaN      F  dollars
# 4  SSSQ.SFMN1111CA  2005.06    1382.692         NaN      F  dollars
#
#    Magnitude                                    Subject  \
# 0          6  Selected Services Survey (ANZSIC06) - SSS
# 1          6  Selected Services Survey (ANZSIC06) - SSS
# 2          6  Selected Services Survey (ANZSIC06) - SSS
# 3          6  Selected Services Survey (ANZSIC06) - SSS
# 4          6  Selected Services Survey (ANZSIC06) - SSS
#
#                                              Group  \
# 0  Industry sales - Subannual Financial Collection
# 1  Industry sales - Subannual Financial Collection
# 2  Industry sales - Subannual Financial Collection
# ...

# %%
# create function rename which convert "dollars" in to "$"
# def rename(name):
#   if name == "dollars":
#     return "$"
#   else:
#     return name

# %%
# call the function rename
# rename("dollars")
# Out:
# '$'

# %%
# change column(UNITS) value "dollars" into "$" using converters and rename
# pd.read_csv("/content/demo.csv", converters={'UNITS' : rename})
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS UNITS  \
# 0     SSSQ.SFMN1111CA  2004.06    1248.356         NaN      F     $
# 1     SSSQ.SFMN1111CA  2004.09    1220.571         NaN      F     $
# 2     SSSQ.SFMN1111CA  2004.12    1263.820         NaN      F     $
# 3     SSSQ.SFMN1111CA  2005.03    1146.156         NaN      F     $
# 4     SSSQ.SFMN1111CA  2005.06    1382.692         NaN      F     $
# ...               ...      ...         ...         ...    ...   ...
# 1195  SSSQ.SFRS2121CT  2023.03         NaN         NaN      C     $
# 1196  SSSQ.SFRS2121CT  2023.06         NaN         NaN      C     $
# 1197  SSSQ.SFRS2121CT  2023.09         NaN         NaN      C     $
# 1198  SSSQ.SFRS2121CT  2023.12         NaN         NaN      C     $
# 1199  SSSQ.SFRS2121CT  2024.03         NaN         NaN      C     $
#
#       Magnitude                                    Subject  \
# 0             6  Selected Services Survey (ANZSIC06) - SSS
# ...

# %%
# convert and column value as null value(NAN) with na_values
# you can add more column value by giving comma(,) in square bracket
# pd.read_csv("/content/demo.csv", na_values=['dollars'])
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS  UNITS  \
# 0     SSSQ.SFMN1111CA  2004.06    1248.356         NaN      F    NaN
# 1     SSSQ.SFMN1111CA  2004.09    1220.571         NaN      F    NaN
# 2     SSSQ.SFMN1111CA  2004.12    1263.820         NaN      F    NaN
# 3     SSSQ.SFMN1111CA  2005.03    1146.156         NaN      F    NaN
# 4     SSSQ.SFMN1111CA  2005.06    1382.692         NaN      F    NaN
# ...               ...      ...         ...         ...    ...    ...
# 1195  SSSQ.SFRS2121CT  2023.03         NaN         NaN      C    NaN
# 1196  SSSQ.SFRS2121CT  2023.06         NaN         NaN      C    NaN
# 1197  SSSQ.SFRS2121CT  2023.09         NaN         NaN      C    NaN
# 1198  SSSQ.SFRS2121CT  2023.12         NaN         NaN      C    NaN
# 1199  SSSQ.SFRS2121CT  2024.03         NaN         NaN      C    NaN
#
#       Magnitude                                    Subject  \
# 0             6  Selected Services Survey (ANZSIC06) - SSS
# ...

# %%
# seprate dataset in to parts by chunksize
# dfs = pd.read_csv("/content/demo.csv", chunksize= 600)

# %%
# print chunks shape
# for chunks in dfs:
#   print(chunks.shape)
# Out:
# (600, 14)
